# %%
# sk-1686176c3c134becb4a6417fb9d7239b

# %%
from langchain_community.llms import tongyi

key = "sk-1686176c3c134becb4a6417fb9d7239b"

llm = tongyi.Tongyi(api_key=key)

llm.invoke('夏天适合吃什么水果？回复几个水果名称就可以了！')
# Out:
# '西瓜、桃子、荔枝、芒果、葡萄、哈密瓜'

# %%
# Ollama本地服务
from langchain_ollama import OllamaLLM

model = OllamaLLM(model="gpt4all", temperature=0.9)

response = model.invoke("夏天适合吃什么水果？回复几个水果名称就可以了")
print(response)
