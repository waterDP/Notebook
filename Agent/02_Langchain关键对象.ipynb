# %%
# 智普AI
key = '8408ad1573274e03becf025b7ea8ed70.X1EBZbPLs756lTXm'
import os
from langchain_community.chat_models import ChatZhipuAI

os.environ["ZHIPUAI_API_KEY"] = key

chat = ChatZhipuAI(
  model="glm-4",
  temperature=0.5,
)

# %%
from langchain_core.prompts import PromptTemplate

# 定义模板
template = '你是一个{role},请用{style}风格回答问题:{question}'

# 创建模板对象
prompt_template = PromptTemplate.from_template(template)

# 变量的填充
# filled_prompt = prompt_template.format(role='数学老师', style='通俗易懂', question='勾股定理是什么？')
filled_prompt = prompt_template.invoke({
  'role': '数学教授',
  'style': '通俗易懂',
  'question': '介绍一下当前的数学前沿研究'
})

# 模型响应数据
ai_msg = chat.invoke(filled_prompt)
print(ai_msg.content)
# Out:
# 同学们好！我是你们的数学教授。今天咱们不聊枯燥的公式，来聊聊数学界最“潮”的研究方向——就像数学界的“顶流明星”一样，这些领域正在被全球数学家们疯狂“追星”呢！
#
#
# ### **第一站：AI与数学的“双向奔赴”**
# 以前我们觉得数学是AI的“老师”（比如微积分、线性代数是AI的基石），现在反过来了——AI成了数学研究的“超级外挂”！
#
# **举个例子：2022年，DeepMind的AI帮数学家解决了一个困扰50年的难题——“扭结理论”中的“诺维科夫猜想”**。数学家们研究了半个世纪的扭结（就是绳子打的结，怎么解、怎么分类），一直有个猜想没证明。结果AI先“看”了海量扭结数据，突然发现了一个隐藏的规律，数学家顺着这个规律，几天就写出了严谨的证明！
#
# **还有更酷的：AI正在帮数学家“猜公式”**。比如研究“朗兰兹纲领”（数学界的“统一理论”，想把数论、几何、分析这些领域串起来），以前数学家靠“拍脑袋”猜猜想，现在AI能从海量数据里找出可能的模式，大大加速了发现速度。
#
# **简单说**：AI不是要取代数学家，而是当“侦察兵”，帮我们发现新大陆，数学家再负责“修地图”（严格证明）。这种“人机协作”，正在让数学研究进入“快车道”！
#
#
# ### **第二站：“宇宙的终极密码”——朗兰兹纲领**
# 如果说数学界有“圣杯”，那一定是“朗兰兹纲领”。这是加拿大数学家朗兰兹在1960年代提出的“大统一理论”，目标是用一根线把数学的“各个部门”串起来：
#
# - **数论**（研究整数，比如“质数有没有无穷多个”）
# - **几何**（研究形状，比如“高维空间有什么秘密”）
# - **分析**（研究变化，比如“微积分的高级版”）
#
# **打个比方**：数学就像一个大森林，以前数论研究“松树”，几何研究“橡树”，分析研究“柳树”，各玩各的。朗兰兹纲领说：其实这些树都长在同一个“生态系”里，它们的“根系”（深层结构）是相通的！
#
# **最近进展**：数学家们正在用“几何朗兰兹纲领”研究“量子场论”（物理里的微观粒子规律），用“数论朗兰兹纲领”研究“密码学”（比如你的手机密码为什么安全）。虽然还没完全解开，但每一步进展，都像在拼“宇宙终极密码”的拼图！
#
#
# ### **第三站：高维空间的“奇幻漂流”**
# 我们生活在3D空间（长、宽、高），但数学家们早就开始“脑补”4D、5D……甚至无限维的空间了！这些“高维空间”不是科幻，而是研究现实世界的重要工具。
#
# **比如“压缩感知”**：你用手机拍照片，像素越高照片越清晰，但数据量超大。数学家发现，在高维空间里，有些“稀疏信号”（比如照片里大部分是背景，只有少量细节）可以用“少量数据”完整重建！这就是为什么现在“拍一张照就能变高清”——背后是高维几何的魔法。
#
# **还有“机器学习的高维诅咒”**：数据维度越高（比如给每个用户打1000个标签），计算越复杂。数学家正在研究“高维空间的几何结构”，让AI在“高维迷宫”里找到“最短路径”，让机器学习更聪明。
#
# **简单说**：高维空间不是“瞎想”，而是解决“大数据”“AI”“物理”等问题的“超级武器”！
#
#
# ### **第四站：数学与物理的“世纪之约”**
# 数学和物理从来不是“邻居”，而是“连体婴”。最近最火的“量子引力”（想把爱因斯坦的相对论和量子力学统一起来），正在向数学“求救”。
#
# **比如“规范场论”**：物理学家用它描述基本粒子的相互作用（比如电磁力、强力），而数学家发现，这玩意儿和“微分几何”（研究弯曲空间的数学）简直是“双胞胎”！物理学家猜的“量子引力模型”，数学家能用“微分几何”翻译成“数学语言”，反过来再验证物理猜想。
#
# **还有“拓扑量子计算”**：传统计算机用“0和1”计算，但“拓扑量子计算机”用“粒子的编织方式”（拓扑结构）计算，抗干扰能力超强。数学家正在研究“高维拓扑”，为这种“未来计算机”设计“算法蓝图”。
#
# **一句话**：物理学家负责“发现宇宙规律”，数学家负责“把这些规律翻译成严谨的语言”，两人一起“解锁宇宙终极奥秘”！
#
#
# ### **第五站：数据科学的“数学引擎”**
# 现在到处都在谈“大数据”“AI”，但背后都是数学在“烧引擎”。
#
# **比如“因果推断”**：以前统计学只能告诉你“A和B相关”（比如“爱喝咖啡的人更容易得肺癌”），但不知道是“咖啡导致肺癌”还是“爱抽烟的人既爱喝咖啡又容易得肺癌”。数学家正在发展“因果图”“反事实推理”等工具，让AI不仅能“看相关性”，还能“找因果性”——这对医学、经济学、AI安全都至关重要。
#
# **还有“优化算法”**：外卖平台怎么规划路线让外卖员最快送达？物流公司怎么仓储让成本最低？这些都是“优化问题”。数学家正在研究“非凸优化”（现实世界的优化问题大多是“非凸”的，像崎岖的山丘，很难找到最高点），让AI能在“复杂地形”里找到“最优解”。
#
#
# ### **最后说句心里话**
# 数学前沿不是“空中楼阁”，而是“解决现实问题的钥匙”。从AI到物理，从数据到宇宙，数学家们正在用“抽象的公式”破解“具体的世界”。
#
# 也许你觉得这些离你很远，但其实：你手机里的AI翻译、你的高清视频、甚至未来的量子计算机，背后都有数学前沿研究的影子。数学就像“空气”，平时感觉不到，但少了它，现代科技就会“窒息”。
#
# 下次再有人说“数学没用”，你可以告诉他：数学家正在“设计未来”，而未来，离不开数学！
#
# 好了，今天的“数学前沿之旅”就到这里，下课有问题随时找我哦～ 😊

# %%
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate

# 定义模板
sys_template = "你是一个数学老师，请以{style}风格回答问题"
user_template = "请用简单易懂的方式解释：{question}"

# 创建对话模板
prompt_template = ChatPromptTemplate.from_messages([
  ("system", sys_template),
  ("human", user_template)
])

# 变量的填充
# prompt = prompt_template.format_messages(style="生动有趣", question="勾股定理是什么？")
prompt = prompt_template.invoke({
  'style': '生动有趣',  
  'question': '勾股定理是什么？'
})

# 获取响应
msg = chat.invoke(prompt)
print(msg.content)
# Out:
# # 勾股定理：三角形的神奇秘密！
#
# 嗨，同学们！今天我们要聊一个超级酷的数学小秘密——勾股定理！想象一下，你有一个直角三角形，就像一块被切开的披萨那样，有一个90度的直角。
#
# 勾股定理告诉我们：在这个直角三角形中，两条直角边的平方和等于斜边的平方！
#
# 用公式表示就是：a² + b² = c²
#
# 这里，a和b是那两条直角边，c是斜边（就是对着直角的那条最长边）。
#
# ## 举个例子：
# 假设你有一个直角三角形，一条直角边是3厘米，另一条是4厘米。那么斜边是多少呢？
#
# 3² + 4² = c²
# 9 + 16 = c²
# 25 = c²
# c = 5厘米
#
# 哇！所以斜边就是5厘米！
#
# ## 实用小知识：
# - 古埃及人用这个原理来确保他们的金字塔是直的！
# - 建筑师用它来设计稳固的建筑物。
# - 游戏开发者用它来计算角色在虚拟世界中的移动距离！
#
# 下次你看到直角三角形时，就可以试试这个神奇的小定理，看看它是不是真的那么神奇！数学世界就是这么有趣！

# %% [markdown]
# ### 输出格式化

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema

# 定义输出结构
response_schemas = [
  ResponseSchema(name='name', description='人的改名',type="string"),  
  ResponseSchema(name='age', description='人的年龄',type="integer")
]

# 创建输出解析器
output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 创建提示词模板，包含格式化指令
template = """你是一个提取助手，请从以下文本中提取姓名和年龄，并以JSON格式返回：
文本：{input_text}
{format_instructions}"""

prompt = PromptTemplate(
  template=template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 填充输入
input_text = '张三今年25岁，来自北京。'
filled_prompt = prompt.format(input_text=input_text)

resp = chat.invoke(filled_prompt)
parsed_output = output_parser.parse(resp.content)
print(parsed_output)
# Out:
# {'name': '张三', 'age': 25}

# %%
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field

# 定义输出模板
class Person(BaseModel):
  name: str = Field(description="人的姓名")
  age: int = Field(description="人的年龄")

# 创建输出解析器
output_parser = PydanticOutputParser(pydantic_object=Person)

# 创建提示模板 
template = """你是一个信息提取助手，请从以下文本中提取姓名和年龄，并以JSON格式返回：
文本：{input_text}
{format_instructions}"""

prompt = PromptTemplate(
  template=template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 填充输入
input_text = '李四今年30岁，来自上海。'
filled_prompt = prompt.format(input_text=input_text)

# 获取输出
resp = chat.invoke(filled_prompt)
parsed_output = output_parser.parse(resp.content)
print(parsed_output)
# Out:
# name='李四' age=30

# %% [markdown]
# ### 链式调用

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import LLMChain

# 定义输出结构
response_schemas = [
  ResponseSchema(name="answer", description="问题的答案", type="string"),
  ResponseSchema(name="confidence", description="答案的置信度", type="float")
]

output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 定义提示模板
template = """你是一个数学老师，请用{style}风格回答以下问题，并以JSON格式返回答案和置信度：
问题：{question}
{format_instructions}"""

prompt = PromptTemplate(
  template = template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 创建一个LLMChain
# lm_chain = LLMChain(llm=chat, prompt=prompt, output_parser=output_parser)
llm_chain = prompt | chat | output_parser

# 运行链
# rs = llm_chain.run({
#   'style': '通俗易懂',
#   'question': '勾股定理是什么？'
# })

rs = llm_chain.invoke({
  'style': '通俗易懂',
  'question': '勾股定理是什么？'
})

print(rs)
# Out:
# {'answer': '勾股定理是一个基本的几何定理，描述了直角三角形三条边之间的关系。简单来说，如果一个三角形是直角三角形，那么两条直角边的平方和等于斜边的平方。用公式表示就是：a² + b² = c²，其中a和b是直角边的长度，c是斜边的长度。这个定理在解决很多实际问题时非常有用，比如测量距离或者建筑设计。', 'confidence': 1.0}

# %% [markdown]
# ### 流式输出

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema
from langchain_core.prompts import PromptTemplate

# 定义输出结构
response_schemas = [
  ResponseSchema(name="answer", description="问题的答案", type="string"),
  ResponseSchema(name="confidence", description="答案的置信度", type="float")
]

output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 定义提示模板
template = """你是一个数学老师，请用{style}风格回答以下问题，并以JSON格式返回答案和置信度：
问题：{question}
{format_instructions}"""

prompt = PromptTemplate(
  template = template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 创建一个LLMChain
llm_chain = prompt | chat 

chunks = []
for chunk in llm_chain.stream({ 'style': '通俗易懂', 'question': '勾股定理是什么？' }):
  chunks.append(chunk)
  print(chunk.content, end="",flush=True)
# Out:
# ```json
# {
# 	"answer": "勾股定理是一个基本的几何定理，描述了直角三角形三条边之间的关系。具体来说，对于一个直角三角形，两条直角边的长度的平方和等于斜边长度的平方。用公式表示就是：a² + b² = c²，其中a和b是直角边的长度，c是斜边的长度。这个定理在解决直角三角形的问题时非常有用，比如计算边长或者判断一个三角形是否为直角三角形。",
# 	"confidence": 1.0
# }
# ```
