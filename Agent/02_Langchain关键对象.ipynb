# %%
# 智普AI
key = '8408ad1573274e03becf025b7ea8ed70.X1EBZbPLs756lTXm'
import os
from langchain_community.chat_models import ChatZhipuAI

os.environ["ZHIPUAI_API_KEY"] = key

chat = ChatZhipuAI(
  model="glm-4",
  temperature=0.5,
)

# %%
from langchain_core.prompts import PromptTemplate

# 定义模板
template = '你是一个{role},请用{style}风格回答问题:{question}'

# 创建模板对象
prompt_template = PromptTemplate.from_template(template)

# 变量的填充
# filled_prompt = prompt_template.format(role='数学老师', style='通俗易懂', question='勾股定理是什么？')
filled_prompt = prompt_template.invoke({
  'role': '数学教授',
  'style': '通俗易懂',
  'question': '预测一下26年的菲奖获得者会是谁？'
})

# 模型响应数据
ai_msg = chat.invoke(filled_prompt)
print(ai_msg.content)
# Out:
# 哈哈，这个问题问得很有意思！不过，作为数学教授，我得先“泼一盆冷水”：**预测菲尔兹奖（Fields Medal）得主，就像预测一场马拉松比赛谁能夺冠一样，几乎是不可能完成的任务。**
#
# 菲奖有“数学界的诺贝尔奖”之称，但它有自己独特的“规矩”和“神秘感”。我先给你讲讲这些“规矩”，你就能明白为什么预测这么难了。
#
# ### 菲尔兹奖的“游戏规则”和“潜规则”
#
# 1.  **年龄限制**：这是最关键的一条！获奖者必须在**颁奖当年的1月1日未满40周岁**。这意味着，2026年的获奖者，必须是1986年1月1日之后出生的人。这个规则一下子就把很多“大器晚成”的数学家排除在外了，也让竞争异常激烈。
#
# 2.  **奖励“过去”，而非“未来”**：菲奖是为了表彰获奖者在**获奖前几年**做出的、被认为是“杰出”和“有重大影响”的工作。它不是奖励你未来的潜力，而是奖励你已经取得的、被公认的成就。所以，我们要找的是那些在近几年已经“引爆”了数学界的人。
#
# 3.  **“非官方”的评审过程**：获奖者由一个国际数学家联盟（IMU）执行委员会秘密选出，整个过程高度保密，没有任何风声。我们外界看到的，往往只是冰山一角。
#
# 4.  **“影响力”是王道**：数学家的工作可能非常深刻，但只有那些能够**连接不同领域、解决重大难题、或者开辟全新研究方向**的工作，才更有可能获奖。它不看你发了多少篇论文，而是看你工作的“重量级”。
#
# ---
#
# ### 那么，我们怎么来“猜一猜”呢？（纯属娱乐，切勿当真！）
#
# 虽然不能预测具体的人，但我们可以根据近几年数学界的热点，来**“圈定”一些热门领域和候选人类型**。2026年的获奖者，很可能就在下面这些方向里产生：
#
# #### **第一梯队：最热门的“种子选手”**
#
# 这些领域在过去十年里取得了革命性的突破，获奖者很可能出自于此。
#
# **1. 朗兰兹纲领与数论**
# *   **为什么火？** 这是现代数学的“终极梦想”之一，试图用统一的框架（朗兰兹纲领）来连接数论、表示论、代数几何等看似毫不相关的领域。最近几年，这个纲领的证明取得了惊人的进展。
# *   **可能的人选？**
#     *   **Peter Scholze**：德国数学家，虽然他已经在2018年获奖了，但他的工作（如完美空间理论）极大地推动了朗兰兹纲领的发展，他合作者的工作也非常值得关注。
#     *   **其他可能的新星**：那些在“几何朗兰兹纲领”或“相对论朗兰兹纲领”中做出关键贡献的年轻数学家。比如，解决了某个长期悬而未决的“引理”或“猜想”的团队核心成员。
#
# **2. 人工智能与数学的交叉**
# *   **为什么火？** 以DeepMind的AlphaTensor（发现了更快的矩阵乘法算法）和AlphaGeometry（在几何证明上达到人类奥林匹克竞赛水平）为代表，AI正在从“辅助证明”走向“发现新定理”。这已经不是一个噱头，而是实实在在改变了数学研究范式。
# *   **可能的人选？**
#     *   **一个“跨界”天才**：可能是一位顶尖的计算机科学家，他/她设计的算法解决了某个重要的数学问题；也可能是一位纯粹数学家，他/她巧妙地运用AI工具，开辟了一个全新的研究领域。这个奖可能会颁给**整个领域的开创者**，而不仅仅是某个人。
#
# **3. 流形与几何拓扑**
# *   **为什么火？** 几何拓扑是研究空间形状的学科。近年来，在4维流形、纽结理论等领域出现了很多深刻的结果。特别是，一些来自物理学的“直觉”（如量子场论）为解决纯数学问题提供了全新的思路。
# *   **可能的人选？**
#     *   **解决某个“世纪难题”的数学家**：比如，在“庞加莱猜想”之后，关于更高维流形的分类问题，或者某个特定流形的“同伦类型”问题被解决的核心人物。
#
# **4. 概率论与统计物理**
# *   **为什么火？** 概率论在描述复杂系统（如金融、网络、生物）中无处不在。近年来，在“随机矩阵”、“随机游走”、“渗流理论”等领域，数学家们得到了一些出人意料的深刻结果，这些结果不仅推动了数学本身，也影响了物理学。
# *   **可能的人选？**
#     *   **一位概率论大师**：他/她可能建立了一个新的理论框架，或者用全新的方法解决了一个长期存在的概率难题，其影响远超概率论本身。
#
# ---
#
# ### 总结一下我的“预测”
#
# 如果非要我给出一个“有根据的猜测”，我会说：
#
# **2026年的菲尔兹奖，极有可能颁发给以下两类人之一：**
#
# *   **类型A：朗兰兹纲领的“新旗手”**。这位数学家可能不是Scholze那样的“王者”，但他/她一定是在这个宏伟纲领的某个关键分支上，做出了决定性贡献的“先锋”。他/她的工作可能让两个原本不相关的数学领域“握手言和”。
#
# *   **类型B：AI+数学交叉领域的“破局者”**。这个人可能是一位数学家，也可能是一位计算机科学家。他/她获奖，不是因为某个具体的定理，而是因为他/她开创了一种**全新的、利用AI进行数学发现的方法**，并成功用它解决了一个重要问题。这个奖项将具有划时代的意义，标志着数学研究进入了一个“人机协作”的新纪元。
#
# **最后，再强调一遍**：以上所有内容，都只是基于数学发展趋势的“合理推测”。菲奖委员会的最终选择，往往充满了惊喜和意外。这正是菲奖的魅力所在——它总能告诉我们，人类的智慧之光，正在我们意想不到的地方闪耀。
#
# 所以，让我们拭目以待，看看2026年数学界会给我们带来怎样的惊喜吧！

# %%
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate

# 定义模板
sys_template = "你是一个数学老师，请以{style}风格回答问题"
user_template = "请用简单易懂的方式解释：{question}"

# 创建对话模板
prompt_template = ChatPromptTemplate.from_messages([
  ("system", sys_template),
  ("human", user_template)
])

# 变量的填充
# prompt = prompt_template.format_messages(style="生动有趣", question="勾股定理是什么？")
prompt = prompt_template.invoke({
  'style': '生动有趣',  
  'question': '勾股定理是什么？'
})

# 获取响应
msg = chat.invoke(prompt)
print(msg.content)
# Out:
# # 勾股定理：三角形的神奇秘密！
#
# 嗨，同学们！今天我们要聊一个超级酷的数学小秘密——勾股定理！想象一下，你有一个直角三角形，就像一块被切开的披萨那样，有一个90度的直角。
#
# 勾股定理告诉我们：在这个直角三角形中，两条直角边的平方和等于斜边的平方！
#
# 用公式表示就是：a² + b² = c²
#
# 这里，a和b是那两条直角边，c是斜边（就是对着直角的那条最长边）。
#
# ## 举个例子：
# 假设你有一个直角三角形，一条直角边是3厘米，另一条是4厘米。那么斜边是多少呢？
#
# 3² + 4² = c²
# 9 + 16 = c²
# 25 = c²
# c = 5厘米
#
# 哇！所以斜边就是5厘米！
#
# ## 实用小知识：
# - 古埃及人用这个原理来确保他们的金字塔是直的！
# - 建筑师用它来设计稳固的建筑物。
# - 游戏开发者用它来计算角色在虚拟世界中的移动距离！
#
# 下次你看到直角三角形时，就可以试试这个神奇的小定理，看看它是不是真的那么神奇！数学世界就是这么有趣！

# %% [markdown]
# ### 输出格式化

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema

# 定义输出结构
response_schemas = [
  ResponseSchema(name='name', description='人的改名',type="string"),  
  ResponseSchema(name='age', description='人的年龄',type="integer")
]

# 创建输出解析器
output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 创建提示词模板，包含格式化指令
template = """你是一个提取助手，请从以下文本中提取姓名和年龄，并以JSON格式返回：
文本：{input_text}
{format_instructions}"""

prompt = PromptTemplate(
  template=template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 填充输入
input_text = '张三今年25岁，来自北京。'
filled_prompt = prompt.format(input_text=input_text)

resp = chat.invoke(filled_prompt)
parsed_output = output_parser.parse(resp.content)
print(parsed_output)
# Out:
# {'name': '张三', 'age': 25}

# %%
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field

# 定义输出模板
class Person(BaseModel):
  name: str = Field(description="人的姓名")
  age: int = Field(description="人的年龄")

# 创建输出解析器
output_parser = PydanticOutputParser(pydantic_object=Person)

# 创建提示模板 
template = """你是一个信息提取助手，请从以下文本中提取姓名和年龄，并以JSON格式返回：
文本：{input_text}
{format_instructions}"""

prompt = PromptTemplate(
  template=template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 填充输入
input_text = '李四今年30岁，来自上海。'
filled_prompt = prompt.format(input_text=input_text)

# 获取输出
resp = chat.invoke(filled_prompt)
parsed_output = output_parser.parse(resp.content)
print(parsed_output)
# Out:
# name='李四' age=30

# %% [markdown]
# ### 链式调用

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import LLMChain

# 定义输出结构
response_schemas = [
  ResponseSchema(name="answer", description="问题的答案", type="string"),
  ResponseSchema(name="confidence", description="答案的置信度", type="float")
]

output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 定义提示模板
template = """你是一个数学老师，请用{style}风格回答以下问题，并以JSON格式返回答案和置信度：
问题：{question}
{format_instructions}"""

prompt = PromptTemplate(
  template = template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 创建一个LLMChain
# lm_chain = LLMChain(llm=chat, prompt=prompt, output_parser=output_parser)
llm_chain = prompt | chat | output_parser

# 运行链
# rs = llm_chain.run({
#   'style': '通俗易懂',
#   'question': '勾股定理是什么？'
# })

rs = llm_chain.invoke({
  'style': '通俗易懂',
  'question': '勾股定理是什么？'
})

print(rs)
# Out:
# {'answer': '勾股定理是一个基本的几何定理，描述了直角三角形三条边之间的关系。简单来说，如果一个三角形是直角三角形，那么两条直角边的平方和等于斜边的平方。用公式表示就是：a² + b² = c²，其中a和b是直角边的长度，c是斜边的长度。这个定理在解决很多实际问题时非常有用，比如测量距离或者建筑设计。', 'confidence': 1.0}

# %% [markdown]
# ### 流式输出

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema
from langchain_core.prompts import PromptTemplate

# 定义输出结构
response_schemas = [
  ResponseSchema(name="answer", description="问题的答案", type="string"),
  ResponseSchema(name="confidence", description="答案的置信度", type="float")
]

output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 定义提示模板
template = """你是一个数学老师，请用{style}风格回答以下问题，并以JSON格式返回答案和置信度：
问题：{question}
{format_instructions}"""

prompt = PromptTemplate(
  template = template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 创建一个LLMChain
llm_chain = prompt | chat 

chunks = []
for chunk in llm_chain.stream({ 'style': '通俗易懂', 'question': '勾股定理是什么？' }):
  chunks.append(chunk)
  print(chunk.content, end="",flush=True)
# Out:
# ```json
# {
# 	"answer": "勾股定理是一个基本的几何定理，描述了直角三角形三条边之间的关系。具体来说，对于一个直角三角形，两条直角边的长度的平方和等于斜边长度的平方。用公式表示就是：a² + b² = c²，其中a和b是直角边的长度，c是斜边的长度。这个定理在解决直角三角形的问题时非常有用，比如计算边长或者判断一个三角形是否为直角三角形。",
# 	"confidence": 1.0
# }
# ```
