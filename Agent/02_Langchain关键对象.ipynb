# %%
# 智普AI
key = '8408ad1573274e03becf025b7ea8ed70.X1EBZbPLs756lTXm'
import os
from langchain_community.chat_models import ChatZhipuAI

os.environ["ZHIPUAI_API_KEY"] = key

chat = ChatZhipuAI(
  model="glm-4",
  temperature=0.5,
)

# %%
from langchain_core.prompts import PromptTemplate

# 定义模板
template = '你是一个{role},请用{style}风格回答问题:{question}'

# 创建模板对象
prompt_template = PromptTemplate.from_template(template)

# 变量的填充
# filled_prompt = prompt_template.format(role='数学老师', style='通俗易懂', question='勾股定理是什么？')
filled_prompt = prompt_template.invoke({
  'role': '数学教授',
  'style': '通俗易懂',
  'question': '介绍一下王虹老师的主要贡献'
})

# 模型响应数据
ai_msg = chat.invoke(filled_prompt)
print(ai_msg.content)
# Out:
# 同学们好！今天咱们来聊聊数学圈里一位特别厉害的“解题高手”——王虹老师。可能有些同学对她还不熟悉，没关系，今天我用大白话给大家讲讲她到底牛在哪儿，让大家知道数学不只是冰冷的公式，更是能解决实际问题的“魔法”。
#
#
# ### **第一站：用“数学显微镜”看“不规则图形”——她的“分数阶微积分”研究**
# 咱们平时学的微积分，比如求导数、积分，处理的都是“光滑”的函数，就像一条没有棱角的曲线。但现实生活中，很多问题可没那么“规矩”——比如材料里的裂纹扩散、地下水在多孔岩石里的流动，甚至大脑神经信号的传递，这些现象的“变化过程”往往带着“粗糙”或“不规则”的特点。
#
# 王虹老师就像给数学装了个“显微镜”，她研究的“分数阶微积分”，就是专门处理这种“不规则变化”的工具。打个比方：如果说普通微积分是“用尺子量长度”，那分数阶微积分就是“用放大镜看细节”——它能更精准地描述那些“不连续”“有毛刺”的变化过程。
#
# 她的成果就像一把“万能钥匙”，打开了好多学科的大门：比如工程师可以用它更准确地预测桥梁的微小形变，医生可以用它更好地分析心电图的异常信号。简单说，她让数学能“听懂”那些“不规矩”的语言，帮我们解决更复杂的问题。
#
#
# ### **第二站：当数学遇上“大数据”——她的“机器学习算法优化”**
# 现在大家天天听“大数据”“人工智能”，但这些“智能”背后，全是数学算法在支撑。不过很多算法有个“小毛病”：计算太慢！比如训练一个AI模型，可能要算上好几天，电脑累得“冒烟”。
#
# 王虹老师看不下去了，她开始琢磨：“怎么让数学算法‘跑’得更快、更聪明？”她带着团队，把抽象的“矩阵理论”“优化理论”和机器学习结合起来，像给算法“装上了 turbo 增压”。比如她提出的“稀疏矩阵快速分解”方法，能让AI处理数据的速度提升好几倍，还更省电——现在很多手机上的语音助手、智能翻译，背后可能就有她的“功劳”。
#
# 她就像一个“算法魔法师”，把复杂的数学变成AI的“加速器”，让大数据不再是“算不动的大块头”，而是能“跑起来”的小助手。
#
#
# ### **第三站：把“数学冷知识”变成“热课堂”——她的教学贡献**
# 除了做研究，王虹老师还是个“数学翻译官”。很多同学觉得数学难，是因为课本上的定义太“抽象”，比如“拓扑学”“泛函分析”，听着就像天书。
#
# 王虹老师最擅长的，就是把“高冷”的数学概念“翻译”成大家能听懂的话。比如讲“拓扑学”，她会拿个甜甜圈和咖啡杯比喻：“你想想，甜甜圈能不能捏成咖啡杯？只要不撕破、不打洞，能！这就是拓扑学的‘橡皮几何’——研究图形在‘拉伸变形’下的不变性质。”她还喜欢用生活例子讲微积分：“你骑自行车，速度越来越快，这就是‘导数’；你骑过的总路程，就是‘积分’。”
#
# 她的课堂总是座无虚席，很多原本害怕数学的同学，听了她的课后突然发现：“原来数学这么有趣！”她还写了好多本“数学科普书”，把大学数学讲得像故事书一样，让更多人爱上数学。
#
#
# ### **总结一下：王虹老师到底做了什么？**
# 简单说，王虹老师做了三件大事：
# 1. **让数学更“精准”**：用分数阶微积分解决“不规则问题”，帮科学和工程“看清”复杂世界；
# 2. **让数学更“高效”**：优化机器学习算法，让AI“跑得更快”，推动智能科技发展；
# 3. **让数学更“可爱”**：用通俗的方式教数学，让“数学恐惧症”的同学也能爱上它。
#
# 她就像一座桥梁，一头连着高深的数学理论，另一头连着我们的生活实际和科技未来。下次当你觉得数学“没用”或“太难”的时候，想想王虹老师——她告诉我们：数学不是冰冷的符号，而是能改变世界的“温暖力量”。
#
# 好啦，今天就聊到这儿，希望大家对王虹老师有个新认识，也对数学多一份热爱！下课！

# %%
from langchain_core.prompts import ChatPromptTemplate

# 定义模板
sys_template = "你是一个数学老师，请以{style}风格回答问题"
user_template = "请用简单易懂的方式解释：{question}"

# 创建对话模板
prompt_template = ChatPromptTemplate.from_messages([
  ("system", sys_template),
  ("human", user_template)
])

# 变量的填充
# prompt = prompt_template.format_messages(style="生动有趣", question="勾股定理是什么？")
prompt = prompt_template.invoke({
  'style': '生动有趣',  
  'question': '勾股定理是什么？'
})

# 获取响应
msg = chat.invoke(prompt)
print(msg.content)
# Out:
# # 勾股定理：三角形的神奇秘密！
#
# 嗨，同学们！今天我们要聊一个超级酷的数学小秘密——勾股定理！想象一下，你有一个直角三角形，就像一块被切开的披萨那样，有一个90度的直角。
#
# 勾股定理告诉我们：在这个直角三角形中，两条直角边的平方和等于斜边的平方！
#
# 用公式表示就是：a² + b² = c²
#
# 这里，a和b是那两条直角边，c是斜边（就是对着直角的那条最长边）。
#
# ## 举个例子：
# 假设你有一个直角三角形，一条直角边是3厘米，另一条是4厘米。那么斜边是多少呢？
#
# 3² + 4² = c²
# 9 + 16 = c²
# 25 = c²
# c = 5厘米
#
# 哇！所以斜边就是5厘米！
#
# ## 实用小知识：
# - 古埃及人用这个原理来确保他们的金字塔是直的！
# - 建筑师用它来设计稳固的建筑物。
# - 游戏开发者用它来计算角色在虚拟世界中的移动距离！
#
# 下次你看到直角三角形时，就可以试试这个神奇的小定理，看看它是不是真的那么神奇！数学世界就是这么有趣！

# %% [markdown]
# ### 输出格式化

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema

# 定义输出结构
response_schemas = [
  ResponseSchema(name='name', description='人的改名',type="string"),  
  ResponseSchema(name='age', description='人的年龄',type="integer")
]

# 创建输出解析器
output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 创建提示词模板，包含格式化指令
template = """你是一个提取助手，请从以下文本中提取姓名和年龄，并以JSON格式返回：
文本：{input_text}
{format_instructions}"""

prompt = PromptTemplate(
  template=template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 填充输入
input_text = '张三今年25岁，来自北京。'
filled_prompt = prompt.format(input_text=input_text)

resp = chat.invoke(filled_prompt)
parsed_output = output_parser.parse(resp.content)
print(parsed_output)
# Out:
# {'name': '张三', 'age': 25}

# %%
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field

# 定义输出模板
class Person(BaseModel):
  name: str = Field(description="人的姓名")
  age: int = Field(description="人的年龄")

# 创建输出解析器
output_parser = PydanticOutputParser(pydantic_object=Person)

# 创建提示模板 
template = """你是一个信息提取助手，请从以下文本中提取姓名和年龄，并以JSON格式返回：
文本：{input_text}
{format_instructions}"""

prompt = PromptTemplate(
  template=template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 填充输入
input_text = '李四今年30岁，来自上海。'
filled_prompt = prompt.format(input_text=input_text)

# 获取输出
resp = chat.invoke(filled_prompt)
parsed_output = output_parser.parse(resp.content)
print(parsed_output)
# Out:
# name='李四' age=30

# %% [markdown]
# ### 链式调用

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import LLMChain

# 定义输出结构
response_schemas = [
  ResponseSchema(name="answer", description="问题的答案", type="string"),
  ResponseSchema(name="confidence", description="答案的置信度", type="float")
]

output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 定义提示模板
template = """你是一个数学老师，请用{style}风格回答以下问题，并以JSON格式返回答案和置信度：
问题：{question}
{format_instructions}"""

prompt = PromptTemplate(
  template = template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 创建一个LLMChain
# lm_chain = LLMChain(llm=chat, prompt=prompt, output_parser=output_parser)
llm_chain = prompt | chat | output_parser

# 运行链
# rs = llm_chain.run({
#   'style': '通俗易懂',
#   'question': '勾股定理是什么？'
# })

rs = llm_chain.invoke({
  'style': '通俗易懂',
  'question': '勾股定理是什么？'
})

print(rs)
# Out:
# {'answer': '勾股定理是一个基本的几何定理，描述了直角三角形三条边之间的关系。简单来说，如果一个三角形是直角三角形，那么两条直角边的平方和等于斜边的平方。用公式表示就是：a² + b² = c²，其中a和b是直角边的长度，c是斜边的长度。这个定理在解决很多实际问题时非常有用，比如测量距离或者建筑设计。', 'confidence': 1.0}

# %% [markdown]
# ### 流式输出

# %%
from langchain_classic.output_parsers import StructuredOutputParser, ResponseSchema
from langchain_core.prompts import PromptTemplate

# 定义输出结构
response_schemas = [
  ResponseSchema(name="answer", description="问题的答案", type="string"),
  ResponseSchema(name="confidence", description="答案的置信度", type="float")
]

output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# 定义提示模板
template = """你是一个数学老师，请用{style}风格回答以下问题，并以JSON格式返回答案和置信度：
问题：{question}
{format_instructions}"""

prompt = PromptTemplate(
  template = template,
  partial_variables={'format_instructions': output_parser.get_format_instructions()}
)

# 创建一个LLMChain
llm_chain = prompt | chat 

chunks = []
for chunk in llm_chain.stream({ 'style': '通俗易懂', 'question': '勾股定理是什么？' }):
  chunks.append(chunk)
  print(chunk.content, end="",flush=True)
# Out:
# ```json
# {
# 	"answer": "勾股定理是一个基本的几何定理，描述了直角三角形三条边之间的关系。具体来说，对于一个直角三角形，两条直角边的长度的平方和等于斜边长度的平方。用公式表示就是：a² + b² = c²，其中a和b是直角边的长度，c是斜边的长度。这个定理在解决直角三角形的问题时非常有用，比如计算边长或者判断一个三角形是否为直角三角形。",
# 	"confidence": 1.0
# }
# ```
